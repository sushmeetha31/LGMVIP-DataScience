# %% [markdown]
# # TASK - 4

# %% [markdown]
# # Image To Pencil Sketch With Python

# %% [markdown]
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# # IMPORTING NECESSARY LIBRARIES

# %%
import cv2
from PIL import Image
from IPython.display import display

# %% [markdown]
# # DISPLAYING THE IMAGE

# %%
real_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(real_img))
# Out:
# <PIL.Image.Image image mode=RGB size=640x638 at 0x2227AEA6EE0>

# %%
#IMAGE IN BGR FORMAT
img = cv2.imread("cat.jpg")
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=640x638 at 0x2227AEA6070>

# %% [markdown]
# # CONVERTING REAL IMAGE TO GRAYSCALE IMAGE

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_img))
# Out:
# <PIL.Image.Image image mode=L size=640x638 at 0x2227AEA6400>

# %% [markdown]
# # CONVERTING INTO NEW GRAYSCALE IMAGE

# %%
newgray_img = 250 - gray_img
display(Image.fromarray(newgray_img))
# Out:
# <PIL.Image.Image image mode=L size=640x638 at 0x2227AEA6220>

# %% [markdown]
# # RESIZING THE IMAGE

# %%
resize_img=cv2.resize(real_img,(450,350))
display(Image.fromarray(resize_img))
# Out:
# <PIL.Image.Image image mode=RGB size=450x350 at 0x2227AEC5430>

# %% [markdown]
# # BLURRING THE IMAGE

# %%
# Using GaussianBlur function
blurred = cv2.GaussianBlur(resize_img, (25,21), 0)
display(Image.fromarray(blurred))
# Out:
# <PIL.Image.Image image mode=RGB size=450x350 at 0x2227AEC5340>

# %% [markdown]
# # CONVERTING IMAGE TO PENCIL SKETCH

# %%
sketch = 250 - gray_img
sketch = cv2.divide(gray_img, newgray_img, scale=130.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=640x638 at 0x2227AE93EB0>

# %% [markdown]
# # COMPARING REAL IMAGE AND PENCIL SKETCH

# %%
display(Image.fromarray(real_img))
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=640x638 at 0x2227AEA6400>
# <PIL.Image.Image image mode=L size=640x638 at 0x2227AEA6E80>
